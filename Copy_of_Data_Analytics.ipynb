# %%
import pandas as pd
import numpy as np
import plotly.express as px
df = pd.read_csv("/content/Train_data.xlsx - Final.csv")
# north_df = df[df["Region"] == "NORTH"]
# north_df
# sum1n = north_df.sum()
# sum2n = pd.DataFrame(sum1n[3:])
# sum3n = sum2n.sum()
# north_sum = sum3n[0]
# south_df = df[df["Region"] == "SOUTH"]
# sum1s = south_df.sum()
# sum2s = pd.DataFrame(sum1s[3:])
# sum3s = sum2s.sum()
# south_sum = sum3s[0]
# east_df = df[df["Region"] == "EAST"]
# east_df
# sum1e = east_df.sum()
# sum2e = pd.DataFrame(sum1e[3:])
# sum3e = sum2e.sum()
# east_sum = sum3e[0]
# east_sum
# west_df = df[df["Region"] == "WEST"]
# west_df
# sum1w = west_df.sum()
# sum2w = pd.DataFrame(sum1w[3:])
# sum3w = sum2w.sum()
# west_sum = sum3w[0]
# west_sum
# random_x = [north_sum,south_sum,east_sum,west_sum]
# names = ['North','South','East','West']
 
# fig = px.pie(values=random_x, names=names,title = "Region-wise aggregrate sales")
# fig.show()

# %%
df["sku"] = df["SKU id"]
north_df = df[df["Region"] == "NORTH"]
south_df = df[df["Region"] == "SOUTH"]
east_df = df[df["Region"] == "EAST"]
west_df = df[df["Region"] == "WEST"]

cnt = 0
vals = [20,31,2,4]
# for x in range(1, 500):
#     sk = "SKU-"+str(x)
#     n = sk in list(north_df.sku)
#     s = sk in list(south_df.sku)
#     w = sk in list(west_df.sku)
#     e = sk in list(east_df.sku)
#     if n&w&e&s:
#         print(sk)
#         cnt += 1
#         vals.append(x)
# print(cnt)

# df = pd.read_csv("train.csv")
# df.head()

north_df = df[df["Region"] == "NORTH"]
south_df = df[df["Region"] == "SOUTH"]
east_df = df[df["Region"] == "EAST"]
west_df = df[df["Region"] == "WEST"]


for x in vals:
    val = x
    print(val)
    e_lst = east_df[east_df["SKU id"] == "SKU-"+str(val)].iloc[0][3:]
    w_lst = west_df[west_df["SKU id"] == "SKU-"+str(val)].iloc[0][3:]
    n_lst = north_df[north_df["SKU id"] == "SKU-"+str(val)].iloc[0][3:]
    s_lst = south_df[south_df["SKU id"] == "SKU-"+str(val)].iloc[0][3:]
    y = north_df.columns[3:]

    pdf = pd.DataFrame()
    pdf["east"] = e_lst
    pdf["north"] = n_lst
    pdf["south"] = s_lst
    pdf["west"] = w_lst
    pdf["month"] = y

    fig = px.line(pdf, y=["east", "north", "west", "south"], x="month",title = "SKU-"+str(val))
    fig.show()
# Out:
# 20
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px
df = pd.read_csv("/content/Train_data.xlsx - Final.csv")

df["sku"] = df["SKU id"]

north_df = df[df["Region"] == "NORTH"]
south_df = df[df["Region"] == "SOUTH"]
east_df = df[df["Region"] == "EAST"]
west_df = df[df["Region"] == "WEST"]

cnt = 0
vals = []
for x in range(1, 500):
    sk = "SKU-"+str(x)
    n = sk in list(north_df.sku)
    s = sk in list(south_df.sku)
    w = sk in list(west_df.sku)
    e = sk in list(east_df.sku)
    if n&w&e&s:
        cnt += 1
        vals.append(x)
print(cnt)


for x in vals[:20]:
    val = x
    print(val)
    e_lst = east_df[east_df["SKU id"] == "SKU-"+str(val)].iloc[0][3:]
    w_lst = west_df[west_df["SKU id"] == "SKU-"+str(val)].iloc[0][3:]
    n_lst = north_df[north_df["SKU id"] == "SKU-"+str(val)].iloc[0][3:]
    s_lst = south_df[south_df["SKU id"] == "SKU-"+str(val)].iloc[0][3:]
    y = north_df.columns[3:]

    pdf = pd.DataFrame()
    pdf["east"] = e_lst
    pdf["north"] = n_lst
    pdf["south"] = s_lst
    pdf["west"] = w_lst
    pdf["month"] = y

    fig = px.line(pdf, y=["east", "north", "west", "south"], x="month", title="SKU-"+str(val))
    fig.show()
# Out:
# 113
# 1
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
 random_x = [31,14,60]
names = ['Increasing Stocks','Decreasing Stocks','Neutral Stocks']
 
fig = px.pie(values=random_x, names=names,title = "Common SKUs sales trend")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
random_x = [31,14,60,7]
names = ['Increasing Stocks','Decreasing Stocks','Neutral Stocks','Outliners']
 
fig = px.pie(values=random_x, names=names,title = "Common SKUs sales trend")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(values=random_x, names=names,title = "Region-wise aggregrate sales")
fig.show()
